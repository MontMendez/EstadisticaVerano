# %% [markdown]
# <a href="https://colab.research.google.com/github/MontMendez/EstadisticaVerano/blob/main/Copia_de_EstadisticaInferencialUnidad01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
print("PROBLEMA 1")
print("1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).")
import pandas as pd
df = pd.DataFrame({
      "examenes_cortos": [59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
      "promedio_final": [64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]})
x = df["examenes_cortos"]
y = df["promedio_final"]
print(df)
plt.show()
print("\n")

print("2. Realice un diagrama de dispersión para estos datos.")
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 4), dpi = 100)
plt.scatter(x, y, label = "Promedio final", color = 'pink')
plt.xlabel('Exámenes cortos') # nombrar eje x
plt.ylabel('Promedio final') # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)
plt.show()
print("\n")

print("3. ¿Los datos soportan la suposición de linealidad?")
print("Sí, soportan la suposición de linealidad, ya que los puntos parecen seguir una secuencia")
plt.show()
print("\n")

print("4. Calcule el coeficiente de correlación e interprete el resultado.")
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')
plt.show()
print("\n")

print("6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.")
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
yc = modelo.predict(x_constante)
plt.plot(x, yc, color = 'grey', linestyle = '--')

import matplotlib.pyplot as plt
plt.figure(figsize=(8,4),dpi=100)
plt.scatter(x,y,
            label="Promedio final",
            color="pink")
plt.title("Gráfico de dispersión")
plt.xlabel("Exámenes cortos")
plt.ylabel("Promedio final")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
yc = modelo.predict(x_constante)
plt.plot(x, yc, color = 'grey', linestyle = '--')
plt.show()
print("\n")

print("5. Calcule el coeficiente de determinación e interprete el resultado.")
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')
plt.show()
print("\n")

print("7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )")
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')
plt.show()
print("\n")

print("8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?")
residuales = modelo.resid
plt.figure()
plt.scatter(x, residuales, color = 'pink')
plt.xlabel('Examenes cortos')
plt.ylabel('Residuales')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()
print("\n")

print("9. Realice la prueba de Shapiro para los residuales y comente el resultado.")
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')
print("No se rechaza ho, por lo tanto la distribución es normal en los residuales")
plt.show()
print("\n")

print("10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.")
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
print("No se rechaza ho, por lo tanto hay homoscedasticidad")
plt.show()
print("\n")

print("11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?")
print(f'para x = 70, y = {modelo.predict([1, 70])}')
print(f'para x = 75, y = {modelo.predict([1, 75])}')
print(f'para x = 84, y = {modelo.predict([1, 84])}\n')
plt.show()
print("\n")

print("12. Realice una tabla ANOVA e interprete el resultado.")
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('promedio_final ~ examenes_cortos', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
print(tabla_anova)
print("Se rechaza ho, por lo tanto b1 es diferente a 0, si hay relación entre x y y")
plt.show()
print("\n")

print("EN CONCLUSIÓN:")
print(("1. Soporta la suposición de linealidad,\n"),
("2. Hay normalidad en los residuales,\n"), #shapiro
("3. Hay homoscedasticidad,\n"), #breusch pagan
("4. Hay relacion entre x y y"))
print("\n")
print("EL MODELO ES CONFIABLE PARA INTERPOLAR")
# Out:
# PROBLEMA 1
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
#     examenes_cortos  promedio_final
# 0                59              64
# 1                92              84
# 2                72              77
# 3                90              80
# 4                95              77
# 5                87              81
# 6                89              80
# 7                77              84
# 8                76              80
# 9                65              69
# 10               97              83
# 11               42              40
# 12               94              78
# 13               62              65
# 14               91              90
#
#
# 2. Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# Sí, soportan la suposición de linealidad, ya que los puntos parecen seguir una secuencia
#
#
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# Coeficiente de correlación:  0.8646
#
#
#
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# Coeficiente de determinación:  0.7475
#
#
#
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
# Intervalo de confianza para b1 de  95%
#  0.4192 < b1 <  0.8671
#
#
#
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# valor-p de Shapiro:  0.9018
#
# No se rechaza ho, por lo tanto la distribución es normal en los residuales
#
#
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# valor_p de Breusch-Pagan:  0.2289
#
# No se rechaza ho, por lo tanto hay homoscedasticidad
#
#
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# para x = 70, y = [69.54941193]
# para x = 75, y = [72.76531124]
# para x = 84, y = [78.55393001]
#
#
#
# 12. Realice una tabla ANOVA e interprete el resultado.
#                    df       sum_sq      mean_sq          F    PR(>F)
# examenes_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual         13.0   519.504375    39.961875        NaN       NaN
# Se rechaza ho, por lo tanto b1 es diferente a 0, si hay relación entre x y y
#
#
# EN CONCLUSIÓN:
# 1. Soporta la suposición de linealidad,
#  2. Hay normalidad en los residuales,
#  3. Hay homoscedasticidad,
#  4. Hay relacion entre x y y
#
#
# EL MODELO ES CONFIABLE PARA INTERPOLAR

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
print("PROBLEMA 2")
print("1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).")
import pandas as pd
df=pd.DataFrame({"salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
                 "ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]})
x = df["salario"]
y = df["ausencias"]
print(df)
plt.show()
print("\n")

print("2. Realice un diagrama de dispersión para estos datos.")
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 4), dpi = 100)
plt.scatter(x, y, label = "ausencias", color = 'pink')
plt.xlabel('salario') # nombrar eje x
plt.ylabel('ausencias') # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)
plt.show()
print("\n")

print("3. ¿Los datos soportan la suposición de linealidad?")
print("Sí, soportan la suposición de linealidad, ya que los puntos parecen seguir una secuencia")
plt.show()
print("\n")

print("4. Calcule el coeficiente de correlación e interprete el resultado.")
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')
plt.show()
print("\n")

print("6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.")
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
yc = modelo.predict(x_constante)
plt.plot(x, yc, color = 'grey', linestyle = '--')

import matplotlib.pyplot as plt
plt.figure(figsize=(8,4),dpi=100)
plt.scatter(x,y,
            label="ausencias",
            color="pink")
plt.title("Gráfico de dispersión")
plt.xlabel("salario")
plt.ylabel("ausencias")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
yc = modelo.predict(x_constante)
plt.plot(x, yc, color = 'grey', linestyle = '--')
plt.show()
print("\n")

print("5. Calcule el coeficiente de determinación e interprete el resultado.")
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')
plt.show()
print("\n")

print("7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )")
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')
plt.show()
print("\n")

print("8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?")
residuales = modelo.resid
plt.figure()
plt.scatter(x, residuales, color = 'pink')
plt.xlabel('salario')
plt.ylabel('Residuales')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()
print("\n")

print("9. Realice la prueba de Shapiro para los residuales y comente el resultado.")
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')
print("No se rechaza ho, por lo tanto la distribución es normal en los residuales")
plt.show()
print("\n")

print("10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.")
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
print("No se rechaza ho, por lo tanto hay homoscedasticidad")
plt.show()
print("\n")

print("11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.")
print("interpolar:")
print(f'para x = 5, y = {modelo.predict([1, 5])}')
print(f'para x = 8, y = {modelo.predict([1, 8])}')
print("extrapolar:")
print(f'para x = 15, y = {modelo.predict([1, 15])}')
print("\n")
plt.show()

print("12. Realice una tabla ANOVA e interprete el resultado.")
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('ausencias ~ salario', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
print(tabla_anova)
print("Se rechaza ho, por lo tanto b1 es diferente a 0, si hay relación entre x y y")
plt.show()
print("\n")

print("EN CONCLUSIÓN:")
print(("1. Soporta la suposición de linealidad,\n"),
("2. Hay normalidad en los residuales,\n"), #shapiro
("3. Hay homoscedasticidad,\n"), #breusch pagan
("4. Hay relacion entre x y y,\n"), #anova r y r2
("5. Hay dependencia entre puntos"))
print("\n")
print("EL MODELO ES CONFIABLE PARA INTERPOLAR")
# Out:
# PROBLEMA 2
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
#     salario  ausencias
# 0        11         18
# 1        10         17
# 2         8         29
# 3         5         36
# 4         9         11
# 5         7         28
# 6         3         35
# 7        11         14
# 8         8         20
# 9         7         32
# 10        2         39
# 11        9         16
# 12        8         31
# 13        3         40
#
#
# 2. Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# Sí, soportan la suposición de linealidad, ya que los puntos parecen seguir una secuencia
#
#
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# Coeficiente de correlación: -0.8801
#
#
#
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# Coeficiente de determinación:  0.7746
#
#
#
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
# Intervalo de confianza para b1 de  95%
# -3.9625 < b1 < -1.9549
#
#
#
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# valor-p de Shapiro:  0.8933
#
# No se rechaza ho, por lo tanto la distribución es normal en los residuales
#
#
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# valor_p de Breusch-Pagan:  0.4505
#
# No se rechaza ho, por lo tanto hay homoscedasticidad
#
#
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# interpolar:
# para x = 5, y = [32.69421488]
# para x = 8, y = [23.81818182]
# extrapolar:
# para x = 15, y = [3.10743802]
#
#
# 12. Realice una tabla ANOVA e interprete el resultado.
#             df      sum_sq     mean_sq          F    PR(>F)
# salario    1.0  983.548996  983.548996  41.243954  0.000033
# Residual  12.0  286.165289   23.847107        NaN       NaN
# Se rechaza ho, por lo tanto b1 es diferente a 0, si hay relación entre x y y
#
#
# EN CONCLUSIÓN:
# 1. Soporta la suposición de linealidad,
#  2. Hay normalidad en los residuales,
#  3. Hay homoscedasticidad,
#  4. Hay relacion entre x y y,
#  5. Hay dependencia entre puntos
#
#
# EL MODELO ES CONFIABLE PARA INTERPOLAR

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
print("PROBLEMA 3")
print("1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).")
import pandas as pd
df = pd.DataFrame({
      "unidades": [40,42,53,35,56,39,48,30,37,40],
      "gastos_generales": [191,170,272,155,280,173,234,116,153,178]})
x = df["unidades"]
y = df["gastos_generales"]
print(df)
print("\n")

print("2. Realice un diagrama de dispersión para estos datos.")
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 4), dpi = 100)
plt.scatter(x, y, label = "gastos_generales", color = 'pink')
plt.xlabel('unidades') # nombrar eje x
plt.ylabel('gastos_generales') # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)
plt.show()
print("\n")

print("3. ¿Los datos soportan la suposición de linealidad?")
print("Sí, soportan la suposición de linealidad, ya que los puntos parecen seguir una secuencia")
plt.show()
print("\n")

print("4. Calcule el coeficiente de correlación e interprete el resultado.")
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')
plt.show()
print("\n")

print("6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.")
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
yc = modelo.predict(x_constante)
plt.plot(x, yc, color = 'grey', linestyle = '--')

import matplotlib.pyplot as plt
plt.figure(figsize=(8,4),dpi=100)
plt.scatter(x,y,
            label="gastos_generales",
            color="pink")
plt.title("Gráfico de dispersión")
plt.xlabel("unidades")
plt.ylabel("gastos_generales")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
yc = modelo.predict(x_constante)
plt.plot(x, yc, color = 'grey', linestyle = '--')
plt.show()
print("\n")

print("5. Calcule el coeficiente de determinación e interprete el resultado.")
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')
plt.show()
print("\n")

print("7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )")
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')
plt.show()
print("\n")

print("8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?")
residuales = modelo.resid
plt.figure()
plt.scatter(x, residuales, color = 'pink')
plt.xlabel('unidades')
plt.ylabel('Residuales')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()
print("\n")

print("9. Realice la prueba de Shapiro para los residuales y comente el resultado.")
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')
print("No se rechaza ho, por lo tanto la distribución es normal en los residuales")
plt.show()
print("\n")

print("10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.")
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
print("No se rechaza ho, por lo tanto hay homoscedasticidad")
plt.show()
print("\n")

print("11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.")
print("interpolar:")
print(f'para x = 38, y = {modelo.predict([1, 38])}')
print(f'para x = 50, y = {modelo.predict([1, 50])}')
print("extrapolar:")
print(f'para x = 26, y = {modelo.predict([1, 26])}')
print("\n")
plt.show()

print("12. Realice una tabla ANOVA e interprete el resultado.")
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('gastos_generales ~ unidades', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
print(tabla_anova)
print("Se rechaza ho, por lo tanto b1 es diferente a 0, si hay relación entre x y y")
plt.show()
print("\n")

print("EN CONCLUSIÓN:")
print(("1. Soporta la suposición de linealidad,\n"),
("2. Hay normalidad en los residuales,\n"), #shapiro
("3. Hay homoscedasticidad,\n"), #breusch pagan
("4. Hay relacion entre x y y")) #anova r y r2
print("\n")
print("EL MODELO ES CONFIABLE PARA INTERPOLAR")
# Out:
# PROBLEMA 3
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
#    unidades  gastos_generales
# 0        40               191
# 1        42               170
# 2        53               272
# 3        35               155
# 4        56               280
# 5        39               173
# 6        48               234
# 7        30               116
# 8        37               153
# 9        40               178
#
#
# 2. Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# Sí, soportan la suposición de linealidad, ya que los puntos parecen seguir una secuencia
#
#
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# Coeficiente de correlación:  0.9835
#
#
#
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# Coeficiente de determinación:  0.9673
#
#
#
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
# Intervalo de confianza para b1 de  95%
#  5.5184 < b1 <  7.4645
#
#
#
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# valor-p de Shapiro:  0.2205
#
# No se rechaza ho, por lo tanto la distribución es normal en los residuales
#
#
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# valor_p de Breusch-Pagan:  0.9858
#
# No se rechaza ho, por lo tanto hay homoscedasticidad
#
#
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# interpolar:
# para x = 38, y = [166.23401361]
# para x = 50, y = [244.13197279]
# extrapolar:
# para x = 26, y = [88.33605442]
#
#
# 12. Realice una tabla ANOVA e interprete el resultado.
#            df        sum_sq       mean_sq           F        PR(>F)
# unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN
# Se rechaza ho, por lo tanto b1 es diferente a 0, si hay relación entre x y y
#
#
# EN CONCLUSIÓN:
# 1. Soporta la suposición de linealidad,
#  2. Hay normalidad en los residuales,
#  3. Hay homoscedasticidad,
#  4. Hay relacion entre x y y
#
#
# EL MODELO ES CONFIABLE PARA INTERPOLAR

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
print("PROBLEMA 4")
print("1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).")
import pandas as pd
df = pd.DataFrame({
      "construccion_casas": [2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
      "ventas_lb": [5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]})
x = df["construccion_casas"]
y = df["ventas_lb"]
print(df)
print("\n")

print("2. Realice un diagrama de dispersión para estos datos.")
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 4), dpi = 100)
plt.scatter(x, y, label = "ventas_lb", color = 'pink')
plt.xlabel('construccion_casas') # nombrar eje x
plt.ylabel('ventas_lb') # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)
plt.show()
print("\n")

print("3. ¿Los datos soportan la suposición de linealidad?")
print("No, no soportan la suposición de linealidad")
plt.show()
print("\n")

print("4. Calcule el coeficiente de correlación e interprete el resultado.")
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')
plt.show()
print("\n")

print("6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.")
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
yc = modelo.predict(x_constante)
plt.plot(x, yc, color = 'grey', linestyle = '--')

import matplotlib.pyplot as plt
plt.figure(figsize=(8,4),dpi=100)
plt.scatter(x,y,
            label="ventas_lb",
            color="pink")
plt.title("Gráfico de dispersión")
plt.xlabel("construccion_casas")
plt.ylabel("ventas_lb")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
yc = modelo.predict(x_constante)
plt.plot(x, yc, color = 'grey', linestyle = '--')
plt.show()
print("\n")

print("5. Calcule el coeficiente de determinación e interprete el resultado.")
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')
plt.show()
print("\n")

print("7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )")
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')
plt.show()
print("\n")

print("8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?")
residuales = modelo.resid
plt.figure()
plt.scatter(x, residuales, color = 'pink')
plt.xlabel('construccion_casas')
plt.ylabel('Residuales')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()
print("\n")

print("9. Realice la prueba de Shapiro para los residuales y comente el resultado.")
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')
print("No se rechaza ho, por lo tanto la distribución es normal en los residuales")
plt.show()
print("\n")

print("10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.")
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
print("No se rechaza ho, por lo tanto hay homoscedasticidad")
plt.show()
print("\n")

print("11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.")
print("interpolar:")
print(f'para x = 3.2, y = {modelo.predict([1, 3.2])}')
print(f'para x = 4.7, y = {modelo.predict([1, 4.7])}')
print("extrapolar:")
print(f'para x = 6.2, y = {modelo.predict([1, 6.2])}')
print("\n")
plt.show()

print("12. Realice una tabla ANOVA e interprete el resultado.")
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('ventas_lb ~ construccion_casas', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
print(tabla_anova)
print("se rechaza ho, por lo tanto b1 es diferente a 0")
print("\n")
plt.show()
print("EN RESUMEN:")
print(("1. No soporta la suposicion de linealidad,\n"),
      ("2. Hay normalidad en los residuales,\n"),
      ("3. Relacion fuerte entre x y y,\n"),
      ("4. Hay homoscedasticidad"))
print("\n")
print("EL MODELO ES CONFIABLE PARA INTERPOLAR, PERO CERO CONFIABLE PARA EXTRAPOLAR")
# Out:
# PROBLEMA 4
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
#    construccion_casas  ventas_lb
# 0                 2.0        5.0
# 1                 2.5        5.5
# 2                 3.2        6.0
# 3                 3.6        7.0
# 4                 3.7        7.2
# 5                 4.0        7.7
# 6                 4.2        8.4
# 7                 4.6        9.0
# 8                 4.8        9.7
# 9                 5.0       10.0
#
#
# 2. Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# No, no soportan la suposición de linealidad
#
#
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# Coeficiente de correlación:  0.9808
#
#
#
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# Coeficiente de determinación:  0.9619
#
#
#
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
# Intervalo de confianza para b1 de  95%
#  1.4557 < b1 <  2.0194
#
#
#
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# valor-p de Shapiro:  0.8464
#
# No se rechaza ho, por lo tanto la distribución es normal en los residuales
#
#
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# valor_p de Breusch-Pagan:  0.1581
#
# No se rechaza ho, por lo tanto hay homoscedasticidad
#
#
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# interpolar:
# para x = 3.2, y = [6.5769642]
# para x = 4.7, y = [9.18331009]
# extrapolar:
# para x = 6.2, y = [11.78965597]
#
#
# 12. Realice una tabla ANOVA e interprete el resultado.
#                      df     sum_sq    mean_sq           F        PR(>F)
# construccion_casas  1.0  25.976581  25.976581  202.069951  5.841003e-07
# Residual            8.0   1.028419   0.128552         NaN           NaN
# se rechaza ho, por lo tanto b1 es diferente a 0
#
#
# EN RESUMEN:
# 1. No soporta la suposicion de linealidad,
#  2. Hay normalidad en los residuales,
#  3. Relacion fuerte entre x y y,
#  4. Hay homoscedasticidad
#
#
# EL MODELO ES CONFIABLE PARA INTERPOLAR, PERO CERO CONFIABLE PARA EXTRAPOLAR

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
print("PROBLEMA 5")
print("1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).")
import pandas as pd
df = pd.DataFrame({
      "interrupciones": [5,10,10,15,15,20,20,25],
      "calificacion_prueba": [58,41,45,27,26,12,16,3]})
x = df["interrupciones"]
y = df["calificacion_prueba"]
print(df)
print("\n")

print("2. Realice un diagrama de dispersión para estos datos.")
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 4), dpi = 100)
plt.scatter(x, y, label = "calificacion_prueba", color = 'pink')
plt.xlabel('interrupciones') # nombrar eje x
plt.ylabel("calificacion_prueba") # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)
plt.show()
print("\n")

print("3. ¿Los datos soportan la suposición de linealidad?")
print("Sí, soportan la suposición de linealidad, ya que los puntos parecen seguir una secuencia")
plt.show()
print("\n")

print("4. Calcule el coeficiente de correlación e interprete el resultado.")
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')
plt.show()
print("\n")

print("6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.")
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
yc = modelo.predict(x_constante)
plt.plot(x, yc, color = 'grey', linestyle = '--')

import matplotlib.pyplot as plt
plt.figure(figsize=(8,4),dpi=100)
plt.scatter(x,y,
            label="calificacion_prueba",
            color="pink")
plt.title("Gráfico de dispersión")
plt.xlabel("interrupciones")
plt.ylabel("calificacion_prueba")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
yc = modelo.predict(x_constante)
plt.plot(x, yc, color = 'grey', linestyle = '--')
plt.show()
print("\n")

print("5. Calcule el coeficiente de determinación e interprete el resultado.")
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')
plt.show()
print("\n")

print("7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )")
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')
plt.show()
print("\n")

print("8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?")
residuales = modelo.resid
plt.figure()
plt.scatter(x, residuales, color = 'pink')
plt.xlabel('interrupciones')
plt.ylabel('Residuales')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()
print("\n")

print("9. Realice la prueba de Shapiro para los residuales y comente el resultado.")
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')
print("No se rechaza ho, por lo tanto la distribución es normal en los residuales")
plt.show()
print("\n")

print("10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.")
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
print("No se rechaza ho, por lo tanto hay homoscedasticidad")
plt.show()
print("\n")

print("11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.")
print("interpolar:")
print(f'para x = 13, y = {modelo.predict([1, 13])}')
print(f'para x = 16, y = {modelo.predict([1, 16])}')
print("extrapolar:")
print(f'para x = 0, y = {modelo.predict([1, 0])}')
print("\n")
plt.show()

print("12. Realice una tabla ANOVA e interprete el resultado.")
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols("calificacion_prueba ~ interrupciones", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
print(tabla_anova)
print("Se rechaza ho, por lo tanto b1 es diferente a 0, si hay relación entre x y y")
plt.show()
print("\n")

print("EN CONCLUSIÓN:")
print(("1. Soporta la suposición de linealidad,\n"),
("2. Hay normalidad en los residuales,\n"), #shapiro
("3. Hay homoscedasticidad,\n"), #breusch pagan
("4. Hay relacion entre x y y")) #anova r y r2
print("\n")
print("EL MODELO ES CONFIABLE PARA INTERPOLAR")
# Out:
# PROBLEMA 5
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
#    interrupciones  calificacion_prueba
# 0               5                   58
# 1              10                   41
# 2              10                   45
# 3              15                   27
# 4              15                   26
# 5              20                   12
# 6              20                   16
# 7              25                    3
#
#
# 2. Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# Sí, soportan la suposición de linealidad, ya que los puntos parecen seguir una secuencia
#
#
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# Coeficiente de correlación: -0.9928
#
#
#
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# Coeficiente de determinación:  0.9858
#
#
#
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
# Intervalo de confianza para b1 de  95%
# -3.1363 < b1 < -2.4637
#
#
#
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# valor-p de Shapiro:  0.0548
#
# No se rechaza ho, por lo tanto la distribución es normal en los residuales
#
#
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# valor_p de Breusch-Pagan:  0.2482
#
# No se rechaza ho, por lo tanto hay homoscedasticidad
#
#
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# interpolar:
# para x = 13, y = [34.1]
# para x = 16, y = [25.7]
# extrapolar:
# para x = 0, y = [70.5]
#
#
# 12. Realice una tabla ANOVA e interprete el resultado.
#                  df  sum_sq      mean_sq           F        PR(>F)
# interrupciones  1.0  2352.0  2352.000000  415.058824  9.090964e-07
# Residual        6.0    34.0     5.666667         NaN           NaN
# Se rechaza ho, por lo tanto b1 es diferente a 0, si hay relación entre x y y
#
#
# EN CONCLUSIÓN:
# 1. Soporta la suposición de linealidad,
#  2. Hay normalidad en los residuales,
#  3. Hay homoscedasticidad,
#  4. Hay relacion entre x y y
#
#
# EL MODELO ES CONFIABLE PARA INTERPOLAR
